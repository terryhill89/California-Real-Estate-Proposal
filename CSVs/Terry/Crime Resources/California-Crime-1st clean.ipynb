# %%
# Import dependencies
import pandas as pd

# %%
# Read the data into a Pandas DataFrame
crimes_info_df = pd.read_csv("Resources/Crimes in California Orignal Data.csv")
crimes_info_df.head()
# Out:
#    Year       County_name                         County_dept  Violent_sum  \
# 0  2021    Alameda County    Alameda Co. Sheriff's Department        10436
# 1  2021     Alpine County     Alpine Co. Sheriff's Department           19
# 2  2021     Amador County     Amador Co. Sheriff's Department          135
# 3  2021      Butte County      Butte Co. Sheriff's Department         1110
# 4  2021  Calaveras County  Calaveras Co. Sheriff's Department          185
#
#    Homicide_sum  Rape_sum  Robbery_sum  AggAssault_sum  PropertyCrime_sum  \
# 0           146      7918         4575            5149              61156
# 1             0         0            0              17                 23
# 2             4        23           13             109                716
# 3            13       178          120             826               4785
# 4             2         6            4             144                677
#
#    Burglary_sum  VehicleTheft_sum  LarcenyTheft_sum  Arson_sum
# ...

# %%
crimes_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               58 non-null     int64
#  1   County_name        58 non-null     object
#  2   County_dept        58 non-null     object
#  3   Violent_sum        58 non-null     int64
#  4   Homicide_sum       58 non-null     int64
#  5   Rape_sum           58 non-null     int64
#  6   Robbery_sum        58 non-null     int64
#  7   AggAssault_sum     58 non-null     int64
#  8   PropertyCrime_sum  58 non-null     int64
#  9   Burglary_sum       58 non-null     int64
#  10  VehicleTheft_sum   58 non-null     int64
#  11  LarcenyTheft_sum   58 non-null     int64
#  12  Arson_sum          58 non-null     int64
# dtypes: int64(11), object(2)
# memory usage: 6.0+ KB

# %%
new_df = pd.melt(crimes_info_df, id_vars=["Year", "County_name", "County_dept"], value_vars= ["Violent_sum", "Homicide_sum", "Rape_sum", "Robbery_sum", "AggAssault_sum", "PropertyCrime_sum", "Burglary_sum", "VehicleTheft_sum", "LarcenyTheft_sum", "Arson_sum"])

# %%
new_df.head()
# Out:
#    Year       County_name                         County_dept     variable  \
# 0  2021    Alameda County    Alameda Co. Sheriff's Department  Violent_sum
# 1  2021     Alpine County     Alpine Co. Sheriff's Department  Violent_sum
# 2  2021     Amador County     Amador Co. Sheriff's Department  Violent_sum
# 3  2021      Butte County      Butte Co. Sheriff's Department  Violent_sum
# 4  2021  Calaveras County  Calaveras Co. Sheriff's Department  Violent_sum
#
#    value
# 0  10436
# 1     19
# 2    135
# 3   1110
# 4    185

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 580 entries, 0 to 579
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         580 non-null    int64
#  1   County_name  580 non-null    object
#  2   County_dept  580 non-null    object
#  3   variable     580 non-null    object
#  4   value        580 non-null    int64
# dtypes: int64(2), object(3)
# memory usage: 22.8+ KB

# %%
new_df.to_csv("Resources/Crimes_2021_Update.csv", index=False)

# %%
new_df.to_json('Crime.json',orient='records')
